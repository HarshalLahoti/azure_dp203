# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# when you click on users you can create new years
#
# #### Steps to follow to create new user
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Adding Role to the datalake
#
# 1. Go to the datalake which is created , go to ccess level

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After this review and create and role is created

# %% [markdown]
# ![image.png](attachment:image.png)
