# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Azure storage account network and firewall setting
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Enabling virtual endpoint
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Managed Identity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
