# %% [markdown]
# #### Data Masking
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# First you need to create key using keyvault and
# ![image-2.png](attachment:image-2.png)
#
# then assign to the syanpse in security tab
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Microsoft Entra ID using syanpse
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Microsoft setting the admin of synapse
#
# 1. Create the User name it as databaseadmin give it role as key
#
# 2. Set the User as an admin in the synapse workspace
#
# ![image.png](attachment:image.png)
#
# 3. Change the Microsoft admin to this user. so first user is not allowed to do anything

# %% [markdown]
# #### creating User and giving accesss to particular DB
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With this it can just access the user database datapool and not the master database

# %% [markdown]
# While creating external table using microsoft intraid you don't need to creditial it will automatically take it.
# just we need to give the user the permission to that container
