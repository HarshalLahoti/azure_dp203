# %% [markdown]
# ### Azure Stream Analytics
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### As part of activity we would read data from event hub into stream analytics job and stored in to dedicated sql pool

# %% [markdown]
# 1. Created syanpse workspace and create sql pools
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. create inout in stream analytical job
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Create the table in datapool in azure syanpse
#
# CREATE TABLE VehicleTollBooth
#
# MakE varchar(100),
# Model varchar(100),
# VehicleType int,
# State varchar(10),
# TollAmount int
#
# )

# %% [markdown]
# 4. Once the input is created it look like this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. before defining the output we need to add storage account
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 6. define Output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. define sql query to define the input and output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. at last the start the job from stream analytics
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://learn.microsoft.com/en-us/stream-analytics-query/built-in-functions-azure-stream-analytics

# %% [markdown]
# ### Event HUB Capture
#
# Azure Event Hub has functionallity called as Event HUB capture which we need to go to the event hub which we have created in that we have cature field
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
